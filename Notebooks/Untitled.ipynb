# %%
import numpy as np

# %%
load_theta = np.load("/mnt/home/fmaion/storage/projects/bias_priors/training_data/theta_log_downsampled.npy", allow_pickle=True)

# %%
for i in range(35):
    if np.max(np.abs(load_theta[:,i])) / np.min(np.abs(load_theta[:,i])) > 100:
        print("This is too large for {:d}".format(i))
        print( np.max(np.abs(load_theta[:,i])), np.min(load_theta[:,i]) )
# Out:
# This is too large for 14
# 3998.800048828125 3.6315999031066895
# This is too large for 23
# 0.9998349547386169 -0.9993056654930115
# This is too large for 27
# 3.9993999004364014 0.0029319999739527702
# This is too large for 28
# 0.999378502368927 -0.33307039737701416
# This is too large for 29
# 4.997700214385986 -4.997700214385986
# This is too large for 31
# 0.999750018119812 -0.999750018119812
